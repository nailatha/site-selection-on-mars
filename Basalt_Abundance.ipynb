# %%
import rasterio
import pandas as pd
import numpy as np

# Buka file GeoTIFF
tif_file = r"D:\ITB\TA\Data\06. Rock Abundance\TES_Basalt_numeric.tif"

with rasterio.open(tif_file) as src:
    
    # Ambil data raster band pertama
    band = src.read(1)
    
    # Ambil ukuran raster
    rows, cols = band.shape
    
    data = []

    # Loop semua pixel
    for row in range(rows):
        for col in range(cols):
            
            # Nilai pixel
            value = band[row, col]
            
            # Skip nilai kosong (NoData)
            if value == src.nodata:
                continue
            
            # Konversi pixel ke koordinat
            lon, lat = src.xy(row, col)
            
            data.append({
                "Longitude": lon,
                "Latitude": lat,
                "Basalt_Abundance": value
            })

# Ubah ke dataframe
df = pd.DataFrame(data)

# Simpan CSV
df.to_csv("basalt_abundance.csv", index=False)

print("Selesai!")
print(df.head())
# Out:
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rasterio\__init__.py:368: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# Selesai!
#    Longitude  Latitude  Basalt_Abundance
# 0        0.5       0.5               0.0
# 1        1.5       0.5               0.0
# 2        2.5       0.5               0.0
# 3        3.5       0.5               0.0
# 4        4.5       0.5               0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca data dari CSV
df_bersih = pd.read_csv(r"D:\ITB\TA\Ngolah Data\06. Rock Abundance\basalt_abundance.csv")

df_bersih["Longitude"] = df_bersih["Longitude"] * 360 / 720
df_bersih["Latitude"] =90 - (df_bersih["Latitude"] * 180 / 360)


# Plot data
plt.figure(figsize=(10, 6))
plt.scatter(df_bersih["Longitude"], df_bersih["Latitude"], c=df_bersih["Basalt_Abundance"], cmap="viridis", s=10)
plt.colorbar(label="Basalt Abundance")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Peta Kelimpahan Basalt (Basalt Abundance)")


plt.show()

# %%
df_after0 = df_bersih[(df_bersih["Basalt_Abundance"] >= 0)]
print(df_after0.head())
# Out:
#    Longitude  Latitude  Basalt_Abundance
# 0       0.25     89.75               0.0
# 1       0.75     89.75               0.0
# 2       1.25     89.75               0.0
# 3       1.75     89.75               0.0
# 4       2.25     89.75               0.0

# %%
counts_after0 = df_after0["Basalt_Abundance"].value_counts().sort_index()

print(counts_after0)
# Out:
# Basalt_Abundance
# 0.000000     99933
# 0.314961       158
# 0.334646        21
# 0.341207         1
# 0.354331        11
#              ...
# 80.196850        1
# 80.216530        2
# 80.236220        3
# 80.295270        2
# 80.314960       22
# Name: count, Length: 9112, dtype: int64

# %%
# Plot data
plt.figure(figsize=(10, 6))
plt.scatter(df_after0["Longitude"], df_after0["Latitude"], c=df_after0["Basalt_Abundance"], cmap="viridis", s=10)
plt.colorbar(label="Basalt Abundance")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Peta Kelimpahan Basalt (Basalt Abundance) >= 0")


plt.show()

# %%
df_nonkutub = df_after0[(df_after0["Latitude"] < 60) & (df_after0["Latitude"] > -60)]
plt.figure(figsize=(14, 6))
plt.scatter(df_nonkutub["Longitude"], df_nonkutub["Latitude"], c=df_nonkutub["Basalt_Abundance"], cmap="viridis", s=10)
plt.colorbar(label="Kelimpahan Basalt")
plt.xlabel("Bujur")
plt.ylabel("Lintang")
plt.title("Peta Kelimpahan Basalt")

plt.show()
