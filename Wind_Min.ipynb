# %%
import rasterio
import pandas as pd
import numpy as np

# Buka file GeoTIFF
tif_file = r"D:\ITB\TA\Data\08. Wind\mars_min_wind.tif"

with rasterio.open(tif_file) as src:
    
    # Ambil data raster band pertama
    band = src.read(1)
    
    # Ambil ukuran raster
    rows, cols = band.shape
    
    data = []

    # Loop semua pixel
    for row in range(rows):
        for col in range(cols):
            
            # Nilai pixel
            value = band[row, col]
            
            # Skip nilai kosong (NoData)
            if value == src.nodata:
                continue
            
            # Konversi pixel ke koordinat
            lon, lat = src.xy(row, col)
            
            data.append({
                "Longitude": lon,
                "Latitude": lat,
                "Speed": value
            })

# Ubah ke dataframe
df = pd.DataFrame(data)

# Simpan CSV
df.to_csv("wind_min.csv", index=False)

print("Selesai!")
print(df.head())
# Out:
# C:\Users\Lenovo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\rasterio\__init__.py:368: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
# Selesai!
#    Longitude  Latitude  Speed
# 0        0.5       0.5    0.0
# 1        1.5       0.5    0.0
# 2        2.5       0.5    0.0
# 3        3.5       0.5    0.0
# 4        4.5       0.5    0.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Baca data dari CSV
df_bersih = pd.read_csv(r"D:\ITB\TA\Ngolah Data\08. Wind\wind_min.csv")

df_bersih["Longitude"] = df_bersih["Longitude"] * 360 / 720
df_bersih["Latitude"] =90 - (df_bersih["Latitude"] * 180 / 360)


# Plot data
plt.figure(figsize=(10, 6))
plt.scatter(df_bersih["Longitude"], df_bersih["Latitude"], c=df_bersih["Speed"], cmap="viridis", s=10)
plt.colorbar(label="Speed")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Peta Kecepatan Angin Minimum di Mars")


plt.show()

# %%
df_after0 = df_bersih[(df_bersih["Speed"] >= 0)]
print(df_after0.head())
# Out:
#    Longitude  Latitude  Speed
# 0       0.25     89.75    0.0
# 1       0.75     89.75    0.0
# 2       1.25     89.75    0.0
# 3       1.75     89.75    0.0
# 4       2.25     89.75    0.0

# %%
counts_after0 = df_after0["Speed"].value_counts().sort_index()

print(counts_after0)
# Out:
# Speed
# 0.000    7200
# 0.001     240
# 0.003     240
# 0.004     240
# 0.005     600
#          ...
# 2.205     120
# 2.230     120
# 2.360     120
# 2.465     120
# 2.716     120
# Name: count, Length: 349, dtype: int64

# %%
# Plot data
plt.figure(figsize=(10, 6))
plt.scatter(df_after0["Longitude"], df_after0["Latitude"], c=df_after0["Speed"], cmap="viridis", s=10)
plt.colorbar(label="Speed")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Peta Kecepatan Angin Minimum di Mars")


plt.show()

# %%
df_nonkutub = df_after0[(df_after0["Latitude"] < 60) & (df_after0["Latitude"] > -60)]
plt.figure(figsize=(14, 6))
plt.scatter(df_nonkutub["Longitude"], df_nonkutub["Latitude"], c=df_nonkutub["Speed"], cmap="viridis", s=10)
plt.colorbar(label="Kecepatan Angin (m/s)")
plt.xlabel("Bujur")
plt.ylabel("Lintang")
plt.title("Peta Kecepatan Angin Minimum Tahunan di Mars")
# balik sumbu y
plt.show()
